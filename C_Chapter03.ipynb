# %% [markdown]
# <a href="https://colab.research.google.com/github/ccwu0918/FS712-C/blob/main/C_Chapter03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 班級: 電機一甲  學號: xxx 姓名: xxx

# %% [markdown]
# # Chapter 03 - 基本資料型態

# %% [markdown]
# ## 3.1 變數與常數

# %%
# !git clone https://github.com/ccwu0918/FS712-C

# %%
cd /content/FS712-C/ch3

# %%
pwd

# %%
# !cat prog3_1.c

# %% [markdown]
# ### prog3_1,變數的使用

# %%
# %%writefile prog3_1.c
# /* prog3_1,變數的使用 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    int num1=12400;	  /* 宣告num1為整數變數，並設值為12400 */
#    double num2=5.234;	  /* 宣告num2為倍精度浮點數變數，並設值為5.234 */
#
#    printf("%d is an integer\n",num1); 	/* 呼叫printf()函數 */
#    printf("%f is a double\n",num2);	/* 呼叫printf()函數 */
#
#    return 0;
# }

# %%
# !gcc prog3_1.c -o prog3_1

# %%
# !./prog3_1

# %% [markdown]
# ## 3.2 基本資料型態

# %% [markdown]
# ### prog3_2, 短整數資料型態的溢位

# %%
# %%writefile prog3_2.c
# /* prog3_2, 短整數資料型態的溢位*/
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    short sum,s=32767;        /* 宣告短整數變數sum與s */
#
#    printf("s= %d\n",s);	/* 列印出s的值 */
#
#    sum=s+1;
#    printf("s+1= %d\n",sum);	/* 列印出sum的值 */
#
#    sum=s+2;
#    printf("s+2= %d\n",sum); 	/* 列印出sum的值 */
#
#    return 0;
# }

# %%
# !gcc prog3_2.c -o prog3_2

# %%
# !./prog3_2

# %% [markdown]
# ### prog3_3, 字元的列印

# %%
# %%writefile prog3_3.c
# /* prog3_3, 字元的列印*/
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    char ch='A';				/* 宣告字元變數ch，並設值為'a' */
#    printf("ch= %c\n",ch);		/* 印出ch的值 */
#    printf("ASCII of ch= %d\n",ch);		/* 印出ch的十進位值 */
#
#    return 0;
# }

# %%
# !gcc prog3_3.c -o prog3_3

# %%
# !./prog3_3

# %% [markdown]
# ### prog3_4, 以ASCII碼設定字元

# %%
# %%writefile prog3_4.c
# /* prog3_4, 以ASCII碼設定字元 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    char ch=90;				/* 將整數90設給字元變數ch */
#    printf("ch=%c\n",ch);		/* 印出ch的值 */
#
#    return 0;
# }

# %%
# !gcc prog3_4.c -o prog3_4

# %%
# !./prog3_4

# %% [markdown]
# ### prog3_5, 數字字元與其相對應的ASCII碼

# %%
# %%writefile prog3_5.c
# /* prog3_5, 數字字元與其相對應的ASCII碼 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    char ch='9';				/* 宣告字元變數ch，並設值為'2' */
#    printf("ch=%c\n",ch);		/* 印出字元變數ch */
#    printf("the ASCII of ch is %d\n",ch);  /* 印出ch的ASCII碼 */
#
#    return 0;
# }

# %%
# !gcc prog3_5.c -o prog3_5

# %%
# !./prog3_5

# %% [markdown]
# ### prog3_6, 字元型態的列印問題

# %%
# %%writefile prog3_6.c
# /* prog3_6, 字元型態的列印問題*/
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    int i=298;
#    printf("ASCII(%d)=%c\n",i,i);	/* 印出ASCII碼為i的字元 */
#
#    return 0;
# }

# %%
# !gcc prog3_6.c -o prog3_6

# %%
# !./prog3_6

# %% [markdown]
# ### prog3_7, 跳脫序列的列印

# %%
# %%writefile prog3_7.c
# /* prog3_7, 跳脫序列的列印*/
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    char beep='\a';		/* 宣告字元變數beep，並設定其值為'\a' */
#    printf("%c", beep);	/* 響一聲警告音 */
#    printf("ASCII of beep=%d", beep);  /* 印出beep的ASCII值 */
#
#    return 0;
# }

# %%
# !gcc prog3_7.c -o prog3_7

# %%
# !./prog3_7

# %% [markdown]
# ### prog3_8, 跳脫序列「\"」的列印

# %%
# %%writefile prog3_8.c
# /* prog3_8, 跳脫序列「\"」的列印 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    char ch='\"';      /* 宣告字元變數ch，並設值為'\"' */
#    printf("%cWe are the World%c\n",ch,ch);       /* 印出字串 */
#    printf("\"We are the World\"\n");       /* 印出字串 */
#    return 0;
# }

# %%
# !gcc prog3_8.c -o prog3_8

# %%
# !./prog3_8

# %% [markdown]
# ### prog3_9, 浮點數的列印

# %%
# %%writefile prog3_9.c
# /* prog3_9, 浮點數的列印 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    float num1=123.45F;		/* 宣告num1為浮點數，並設值為123.45F */
#    float num2=4.56E-3F;	/* 宣告num2為浮點數，並設值為4.56E-3F */
#
#    printf("num1=%e\n",num1); 	/* 以指數的型態印出num1的值 */
#    printf("num2=%f\n",num2); 	/* 以浮點數的型態印出num2的值 */
#
#    return 0;
# }

# %%
# !gcc prog3_9.c -o prog3_9

# %%
# !./prog3_9

# %% [markdown]
# ### prog3_10, float與double精度的比較

# %%
# %%writefile prog3_10.c
# /* prog3_10, float與double精度的比較 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    float  num1=123.456789012345F; /* 宣告num1為float，並設定初值 */
#    double num2=123.456789012345;  /* 宣告num2為double，並設定初值 */
#
#    printf("num1=%16.12f\n",num1); /* 列印出浮點數num1的值 */
#    printf("num2=%16.12f\n",num2); /* 列印出倍精度浮點數num2的值 */
#
#    return 0;
# }

# %%
# !gcc prog3_10.c -o prog3_10

# %%
# !./prog3_10

# %% [markdown]
# ## 3.3 查詢常數、變數或資料型態所佔位元組

# %% [markdown]
# ### prog3_11, 列印出各種資料型態的長度

# %%
# %%writefile prog3_11.c
# /* prog3_11, 列印出各種資料型態的長度 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    char ch;			/* 宣告字元變數ch */
#    float num;			/* 宣告浮點數變數num */
#
#    printf("sizeof(2L)=%d\n",sizeof(2L));	/* 查詢常數2L所佔位元組 */
#
#    printf("sizeof(ch)=%d\n",sizeof(ch));	/* 查詢字元變數ch所佔位元組 */
#    printf("sizeof(num)=%d\n",sizeof(num));	/* 查詢變數num所佔位元組 */
#
#    printf("sizeof(int)=%d\n",sizeof(int));	/* 查詢int型態所佔位元組 */
#    printf("sizeof(long)=%d\n",sizeof(long));	/* 查詢long型態所佔位元組 */
#    printf("sizeof(short)=%d\n",sizeof(short));	/* 查詢short所佔位元組 */
#    printf("sizeof(float)=%d\n",sizeof(float));	/* 查詢float所佔位元組 */
#
#    printf("sizeof(double)=%d\n",sizeof(double));	/* 查詢double所佔位元組 */
#
#    return 0;
# }

# %%
# !gcc prog3_11.c -o prog3_11

# %%
# !./prog3_11

# %% [markdown]
# ## 3.4 資料型態的轉換

# %% [markdown]
# ### prog3_12, 資料型態的轉換

# %%
# %%writefile prog3_12.c
# /* prog3_12, 資料型態的轉換*/
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    int n1,n2;
#    float num1=3.002F,num2=3.988F;
#
#    n1=(int) num1;		/* 將浮點數num1轉換成整數 */
#    n2=(int) num2; 	/* 將浮點數num2轉換成整數 */
#
#    printf("num1=%f, num2=%f\n",num1,num2);  /* 印出浮點數的值 */
#    printf("n1=%d, n2=%d\n",n1,n2);  /* 印出浮點數轉成整數後的值 */
#
#    return 0;
# }

# %%
# !gcc prog3_12.c -o prog3_12

# %%
# !./prog3_12

# %% [markdown]
# ### prog3_13, 資料型態的轉換

# %%
# %%writefile prog3_13.c
# /* prog3_13, 資料型態的轉換*/
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    int num=5;
#
#    printf("num/2=%d\n",num/2);			/* 整數相除 */
#    printf("(float)num/2=%.2f\n",(float)num/2);	/* 將整數轉成浮點數，再做除法 */
#
#    return 0;
# }

# %%
# !gcc prog3_13.c -o prog3_13

# %%
# !./prog3_13

# %% [markdown]
# ### Question 3-2：
# 試修改 prog3_1，使得第 9 行與第 10 行可分別印出 num1 與 num2 的平方值。第 9 行與第 10 行的輸出結果應如下所示：
#
# ```
# num1 的平方為 153760000
# num2 的平方為 27.394756
# ```

# %%
# %%writefile hw3_2.c
# // hw3_2, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# num1 的平方為 153760000
# num2 的平方為 27.394756
#
# ----------------------------------*/

# %%
# !gcc hw3_2.c -o hw3_2

# %%
# !./hw3_2

# %% [markdown]
# ### Question 3-12：
# 試寫一程式，利用設定字元變數 ch 為 ASCII 碼的方式讓電腦發出一個警告音（警告音的 ASCII 碼為 7）。

# %%
# %%writefile hw3_12.c
# // hw3_12, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
#
# ----------------------------------*/

# %%
# !gcc hw3_12.c -o hw3_12

# %%
# !./hw3_12

# %% [markdown]
# ### Question 3-13：
# 請參閱下面的程式碼，然後回答接續的問題：
#
# ```
# /* hw13_14, 數字溢位的練習 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    unsigned short num=80000;
#    printf("%d\n",num);
#
#    return 0;
# }
# ```
#
# (a) 試說明執行此程式的結果，為什麼是 14464，而不是 80000 這個數字？
#
# (b) 如果想讓本題第 7 行的執行結果恰好為 80000，應如何修改程式碼？

# %%
# %%writefile hw3_14.c
# // hw3_14, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# 14464
#
# ----------------------------------*/

# %%
# !gcc hw3_14.c -o hw3_14

# %%
# !./hw3_14

# %% [markdown]
# ### Question 3-15：
# 請參閱下面的程式碼，然後回答接續的問題：
#
#
#
# ```
# /* hw3_15, 數字精度的問題 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    float num1=30000.1F;
#    float num2=0.0004F;
#    printf("%f\n",num1+num2);
#
#    system("pause");
#    return 0;
# }
# ```
#
#
# (a) 試執行此程式碼，您會得到什麼結果？
#
# (b) 於數學上，$30000.1 + 0.0004 = 30000.1004$，試說明執行此程式碼後，為什麼得不到這個結果？
#
# (c) 如果想讓本題的執行結果恰好為 30000.1004，應如何改進？試撰寫一個完整的程式碼來改進之。

# %%
# %%writefile hw3_15a.c
# // hw3_15a, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# 30000.099609
#
# ----------------------------------*/

# %%
# !gcc hw3_15a.c -o hw3_15a

# %%
# !./hw3_15a

# %%
# %%writefile hw3_15c.c
# // hw3_15c, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# 30000.1004
#
# ----------------------------------*/

# %%
# !gcc hw3_15c.c -o hw3_15c

# %%
# !./hw3_15c

# %% [markdown]
# ### Question 3-16：
# 試撰寫一程式，利用 sizeof 關鍵字查詢下列各種資料型態所佔的位元組：
#
#
# ```
#
# (a) unsigned int
#
# (b) double
#
# (c) unsigned short int
# ```

# %%
# %%writefile hw3_16.c
# // hw3_16, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#
#
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# sizeof(unsigned int) = 4
# sizeof(double) = 8
# sizeof(unsigned short int) = 2
#
# ----------------------------------*/

# %%
# !gcc hw3_16.c -o hw3_16

# %%
# !./hw3_16

# %% [markdown]
# ### Question 3-17：
# 試撰寫一程式，利用 sizeof 關鍵字查詢下列各常數所佔的位元組：
#
#
# ```
# (a) 578
#
# (b) 784000000
#
# (c) 6.78f
#
# (d) 718.26
#
# (e) 6.42e127
# ```

# %%
# %%writefile hw3_17.c
# // hw3_17, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#
#
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# sizeof(578) = 4
# sizeof(784000000) = 4
# sizeof(6.78f) = 4
# sizeof(718.26) = 8
# sizeof(6.42e127) = 8
#
# ----------------------------------*/

# %%
# !gcc hw3_17.c -o hw3_17

# %%
# !./hw3_17

# %% [markdown]
# ### Question 3-18：
# 假設浮點數變數 num1 與 num2 的值分別為 123.39f 與 3.8e5f，試撰寫一程式，將這兩個變數值轉換成整數。

# %%
# %%writefile hw3_18.c
# // hw3_18, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#
#
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# num1(before)= 123.389999
# num2(before)= 380000.000000
# num1(after)= 123
# num2(after)= 380000
#
# ----------------------------------*/

# %%
# !gcc hw3_18.c -o hw3_18

# %%
# !./hw3_18

# %% [markdown]
# ### Question 3-19：
# 請參閱下面的程式碼，然後回答接續的問題：
#
#
# ```
# /* hw3_19, 型態轉換的練習 */
# #include <stdio.h>
# #include <stdlib.h>
# int main(void)
# {
#    int num1=5,num2=8;
#    printf("%d\n",num1/num2);
#
#    return 0;
# }
# ```
#
#
# (a) 試解釋第 7 行的輸出結果為何是 0？
#
# (b) 試修改程式碼，利用型態轉換的方式，使得第 7 行的輸出結果為 0.625000。

# %%
# %%writefile hw3_19.c
# // hw3_19, 班級: 電機一甲  學號: xxx 姓名: xxx
# #include <stdio.h>
# #include <stdlib.h>
# int main(void){
#
#
#
#
#
#
#     return 0;
#
# }
#
# /* output---------------------------
#
# 0.625000
#
# ----------------------------------*/

# %%
# !gcc hw3_19.c -o hw3_19

# %%
# !./hw3_19
